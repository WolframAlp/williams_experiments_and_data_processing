# %% [markdown]
# # Mapping between different extraction range spaces

# %%
# %matplotlib widget
from emission_curves import EmissionCurve
from mapping_tools import *
import numpy as np

# %%
emap = EMap(-1000)

# %%
emap.show_map()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
emap.show_3dmap()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
emap.rs[-1] - emap.rs[0]

# %%
np.arctan(0.5)*180 / np.pi
# Out:
# 26.56505117707799

# %%
emap.angles[0]
# Out:
# array([1.00000000e-05, 5.24556873e-03, 1.04811375e-02, 1.57167062e-02,
#        2.09522749e-02, 2.61878437e-02, 3.14234124e-02, 3.66589811e-02,
#        4.18945499e-02, 4.71301186e-02, 5.23656873e-02, 5.76012561e-02,
#        6.28368248e-02, 6.80723935e-02, 7.33079623e-02, 7.85435310e-02,
#        8.37790997e-02, 8.90146685e-02, 9.42502372e-02, 9.94858059e-02,
#        1.04721375e-01, 1.09956943e-01, 1.15192512e-01, 1.20428081e-01,
#        1.25663650e-01, 1.30899218e-01, 1.36134787e-01, 1.41370356e-01,
#        1.46605925e-01, 1.51841493e-01, 1.57077062e-01, 1.62312631e-01,
#        1.67548199e-01, 1.72783768e-01, 1.78019337e-01, 1.83254906e-01,
#        1.88490474e-01, 1.93726043e-01, 1.98961612e-01, 2.04197181e-01,
#        2.09432749e-01, 2.14668318e-01, 2.19903887e-01, 2.25139456e-01,
#        2.30375024e-01, 2.35610593e-01, 2.40846162e-01, 2.46081730e-01,
#        2.51317299e-01, 2.56552868e-01, 2.61788437e-01, 2.67024005e-01,
# ...
